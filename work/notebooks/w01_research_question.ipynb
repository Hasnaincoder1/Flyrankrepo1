# %% [markdown]
# <a href="https://colab.research.google.com/github/Hasnaincoder1/Flyrankrepo1/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Hasnaincoder1/Flyrankrepo1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# My lane is road damage detection using YOLO11 fine-tuned on RDD2022. I chose this because it's a scoped, finishable project for a 7-week window with a clear academic baseline (pretrained vs fine-tuned), rather than a broader system I couldn't complete well.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# My lane is road damage detection using YOLO11 trained on RDD2022. I chose this over a broader monitoring system because it's a narrower, shippable scope I can actually finish in 7 weeks, and it gives me a concrete research angle — how well a model trained on RDD2022 generalizes to local Pakistani road footage — which is citable and specific enough for a university application, rather than a vague I built an AI appclaim.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# This is a proof-of-concept, not a deployed system, but the decision it's designed to eventually support is: which road segments a municipal road authority should prioritize for inspection. A false negative means real damage goes unflagged; a false positive wastes inspection time. Since there's no live deployment, the actual cost right now is reputational/academic, an unreliable model undermines the credibility of the proof-of-concept itself.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# The decision this supports is which stretches of road a maintenance team should prioritize for inspection. A city or contractor would act on the flagged list. A wrong call has two costs: a false negative means a real pothole/crack goes unflagged and gets worse (or causes an accident) before anyone notices; a false positive wastes an inspector's time driving out to a segment with nothing wrong. Given the safety angle, missing real damage is the costlier error.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# import pandas as pd
#
# df = pd.read_csv("data/raw/rdd2022.csv")
# print(df.shape)
# print(df["class"].value_counts())

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# This project can say: detections are observed on the RDD2022 evaluation set; the fine-tuned model's performance vs. the pretrained baseline is a measured, directional comparison. It cannot say: the model works on Pakistani roads (untested), that it's ready for real municipal deployment, or anything causal about why damage occurs. It's a research prototype, not a deployed decision system.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# This project can say: the model's detections are observed on the evaluation set; performance differences between RDD2022 and local footage are directional evidence of domain shift; the output supports (not replaces) an inspector's decision. It cannot say: the model proves which roads are dangerous, that detection rate equals real-world damage rate, or anything about roads/regions not represented in the data. No causal claims about why damage occurs.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
