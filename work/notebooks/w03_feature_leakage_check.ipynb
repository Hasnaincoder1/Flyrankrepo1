# %% [markdown]
# <a href="https://colab.research.google.com/github/Hasnaincoder1/Flyrankrepo1/blob/main/work/notebooks/w03_feature_leakage_check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-05 — Feature Vector and Leakage/Privacy Check
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Hasnaincoder1/Flyrankrepo1/blob/main/work/notebooks/w03_feature_leakage_check.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Build the feature vector
#
# *Code that actually builds it. engineered features, categorical handling, fills.*
#
# For this object detection task, the "feature vector" is the image itself (raw pixels), which YOLO11 processes internally through its convolutional backbone there's no hand-engineered tabular feature vector as in classic ML. The only additional metadata field I use is the country/source tag if present in RDD2022, purely for reporting/analysis, not as a model input.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Feature notes (meaning, missing, categorical, available-when?)
#
# *For each feature: what it means, how missing values are handled, and whether it exists BEFORE the moment you predict.*
#
# The primary input is raw image pixels. No missing-value handling needed since every image is complete by construction. Country/source metadata (if used) is categorical, known before prediction, and never derived from the label. No feature in this pipeline is computed after or from the outcome, since there's no "outcome" separate from the label itself in detection.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. The leakage hunt
#
# *Attack your own features: label-derived columns, future windows, product flags. Show the test.*
#
# I checked for leakage by confirming that no feature used at prediction time is derived from the label. Since input is raw pixel data and the label is the bounding box + class annotation drawn independently by annotators, there's no overlap between feature and label columns to leak. Unlike tabular projects where a feature might secretly encode the target, image-input detection makes this failure mode structurally less likely, the risk here is instead about split-level leakage, e.g. the same road or nearly identical images appearing in both train and test sets, which I address in the train/val/test split design rather than at the feature level.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. What I excluded and why
#
# *The list of fields you refused to use — with one line of why each.*
#
# I excluded any RDD2022 metadata fields not useful for this task (e.g. exact GPS coordinates if present, timestamp of capture) since they're not used as model inputs and including them risks accidentally identifying source location in ways that could bias evaluation. I also excluded any damage classes beyond the four core ones (D00, D10, D20, D40) if RDD2022 includes rarer/ambiguous labels, to keep the class set clean and comparable to published baselines.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
